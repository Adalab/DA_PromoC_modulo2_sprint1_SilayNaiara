# %% [markdown]
# el 4 no lo entendemos

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Pair Programming Pandas V**

# %% [markdown]
# En este ejercicio pondremos en práctica los conceptos básicos para juntar varios csv que compartan información.
# Trabajaremos con tres ficheros diferentes:
#
#
# - El csv que creamos en el ejercicio de pair programming Pandas IV, dónde recordamos eliminamos ciertas columnas que no eran necesarias, y habíamos creado nuevas.
# - El csv llamado attacks_historico donde tenemos información sobre los ataques de tiburón previos al año 1800, este fichero lo tenéis un poco mas abajo para descargar.
# - El csv llamado attacks_adicional donde tenemos información sobre los ataques de tiburón. de nuevo, este fichero lo tenéis abajo para descargar.
#
#
# El principal objetivo de este ejercicio de pair programming es acabar teniendo un único DataFrame con toda la información contenida en los tres csv anteriores.
#
#
# Para llevar a cabo nuestro objetivo tendréis que seguir los siguientes pasos:

# %% [markdown]
# 1. Cargad los tres ficheros nombrados anteriormente y los exploramos para familizarizarnos con ellos y saber que información tienen en común y debatir con tu compañera como podríamos juntar toda la información.

# %% [markdown]
# como no teer columna unnamed:
# cuando hago la importa

# %%
tiburones = pd.read_csv("tiburones_menos10.csv",index_col=0)
tiburones.head()
# Out:
#             UNNAMED: 0   CASE NUMBER    YEAR        TYPE    COUNTRY  \
# Unnamed: 0
# 0                    0    2018.06.25  2018.0     Boating        USA
# 6                    6  2018.06.03.a  2018.0  Unprovoked     BRAZIL
# 8                    8  2018.05.26.b  2018.0  Unprovoked        USA
# 10                  10    2018.05.24  2018.0    Provoked  AUSTRALIA
# 13                  13  2018.05.13.a  2018.0     Invalid    ENGLAND
#
#                   AREA                      LOCATION        ACTIVITY  \
# Unnamed: 0
# 0           California   Oceanside, San Diego County        Paddling
# 6           Pernambuco         Piedade Beach, Recife        Swimming
# 8              Florida  Cocoa Beach, Brevard  County         Walking
# 10          Queensland               Cairns Aquarium  Feeding sharks
# 13            Cornwall                Off Land's End         Fishing
#
#                               NAME SEX  AGE            TIME          SPECIES   \
# Unnamed: 0
# 0                      Julie Wolfe    F  57           18h00       White shark
# 6           Jose Ernesto da Silva     M  18  Late afternoon       Tiger shark
# 8                        Cody High    M  15           17h00    Bull shark, 6'
# 10                            male    M  32         Morning   Grey reef shark
# 13                    Max Berryman    M  21           08h15  Invalid incident
#
#                                       PDF  \
# Unnamed: 0
# 0                    2018.06.25-Wolfe.pdf
# 6                2018.06.03.a-daSilva.pdf
# 8                   2018.05.26.b-High.pdf
# 10          2018.05.24-CairnsAquarium.pdf
# 13              2018.05.13.a-Berryman.pdf
#
#                                                          HREF
# Unnamed: 0
# 0           http://sharkattackfile.net/spreadsheets/pdf_di...
# 6           http://sharkattackfile.net/spreadsheets/pdf_di...
# 8           http://sharkattackfile.net/spreadsheets/pdf_di...
# 10          http://sharkattackfile.net/spreadsheets/pdf_di...
# 13          http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
ataques = pd.read_csv("attacks_historico.csv")
ataques.head()
# Out:
#    Unnamed: 0   Case Number    Year        Type     Country             Area  \
# 0        6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES         St. Anne
# 1        6133  1797.05.28.R  1797.0  Unprovoked         NaN              NaN
# 2        6134    1792.09.12  1792.0    Provoked     ENGLAND              NaN
# 3        6135    1791.00.00  1791.0  Unprovoked   AUSTRALIA  New South Wales
# 4        6136    1788.05.10  1788.0        Boat   AUSTRALIA  New South Wales
#
#               Location                         Activity  \
# 0                  NaN  a corsair's boat was overturned
# 1                  NaN                Dropped overboard
# 2  On the Thames River                          Fishing
# 3         Port Jackson                              NaN
# 4        Sydney Harbor                          Fishing
#
#                                Name Sex   ... Species   \
# 0                               NaN    F  ...      NaN
# 1                             child  NaN  ...      NaN
# 2                              male    M  ...      NaN
# 3  female, an Australian aboriginal    F  ...      NaN
# 4                              boat  NaN  ...      NaN
#
#                               Investigator or Source  \
# 0                                 V. C. Harvey-Brain
# 1                             The Observer 5/28/1797
# 2                    The Waterford Herald, 9/15/1792
# 3                 G.P. Whitley;  D. Baldridge, p.162
# 4  G.P. Whitley citing J. Cobley, Sydney Cove, p....
#
#                                pdf  \
# 0      1800.00.00-Corsair-boat.pdf
# 1      1797.05.28.R-Cloverdale.pdf
# 2            1792.09.12-Thames.pdf
# 3  1791.00.00-aboriginal woman.pdf
# 4                1788.05.10-Sydney
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    1800.00.00
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  1797.05.28.R
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    1792.09.12
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    1791.00.00
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    1788.05.10
#
#   Case Number.2 original order Unnamed: 22  Unnamed: 23
# 0    1800.00.00          171.0         NaN          NaN
# 1  1797.05.28.R          170.0         NaN          NaN
# 2    1792.09.12          169.0         NaN          NaN
# 3    1791.00.00          168.0         NaN          NaN
# 4    1788.05.10          167.0         NaN          NaN
#
# [5 rows x 22 columns]

# %%
ataques_adicional = pd.read_csv("attacks_adicional.csv")
ataques_adicional.head()
# Out:
#    Unnamed: 0 Case Number Fatal (Y/N)  \
# 0           0  2018.06.25           N
# 1           1  2018.06.18           N
# 2           2  2018.06.09           N
# 3           3  2018.06.08           N
# 4           4  2018.06.04           N
#
#                                               Injury         Date
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 1                         Minor injury to left thigh  18-Jun-2018
# 2       Injury to left lower leg from surfboard skeg  09-Jun-2018
# 3                          Minor injury to lower leg  08-Jun-2018
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT  04-Jun-2018

# %% [markdown]
# 2. Chequead que los nombres de las columnas ver si se llaman iguales entre dataframes . ¿Están todas en minúsculas? ¿Tienen espacios? En caso de que no sean todas iguales unificad el nombre de las columnas.

# %%
tiburones.columns
# Out:
# Index(['UNNAMED: 0', 'CASE NUMBER', 'YEAR', 'TYPE', 'COUNTRY', 'AREA',
#        'LOCATION', 'ACTIVITY', 'NAME', 'SEX ', 'AGE', 'TIME', 'SPECIES ',
#        'PDF', 'HREF'],
#       dtype='object')

# %%
tiburones_elim= tiburones.drop(['UNNAMED: 0'], axis=1)
tiburones_elim.head()
# Out:
#              CASE NUMBER    YEAR        TYPE    COUNTRY        AREA  \
# Unnamed: 0
# 0             2018.06.25  2018.0     Boating        USA  California
# 6           2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8           2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 10            2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 13          2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                                 LOCATION        ACTIVITY  \
# Unnamed: 0
# 0            Oceanside, San Diego County        Paddling
# 6                  Piedade Beach, Recife        Swimming
# 8           Cocoa Beach, Brevard  County         Walking
# 10                       Cairns Aquarium  Feeding sharks
# 13                        Off Land's End         Fishing
#
#                               NAME SEX  AGE            TIME          SPECIES   \
# Unnamed: 0
# 0                      Julie Wolfe    F  57           18h00       White shark
# 6           Jose Ernesto da Silva     M  18  Late afternoon       Tiger shark
# 8                        Cody High    M  15           17h00    Bull shark, 6'
# 10                            male    M  32         Morning   Grey reef shark
# 13                    Max Berryman    M  21           08h15  Invalid incident
#
#                                       PDF  \
# Unnamed: 0
# 0                    2018.06.25-Wolfe.pdf
# 6                2018.06.03.a-daSilva.pdf
# 8                   2018.05.26.b-High.pdf
# 10          2018.05.24-CairnsAquarium.pdf
# 13              2018.05.13.a-Berryman.pdf
#
#                                                          HREF
# Unnamed: 0
# 0           http://sharkattackfile.net/spreadsheets/pdf_di...
# 6           http://sharkattackfile.net/spreadsheets/pdf_di...
# 8           http://sharkattackfile.net/spreadsheets/pdf_di...
# 10          http://sharkattackfile.net/spreadsheets/pdf_di...
# 13          http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
tiburones_sinespacios = tiburones_elim.replace(" ", "_")
tiburones_sinespacios.head()
# Out:
#              CASE_NUMBER    YEAR        TYPE    COUNTRY        AREA  \
# Unnamed: 0
# 0             2018.06.25  2018.0     Boating        USA  California
# 6           2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8           2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 10            2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 13          2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                                 LOCATION        ACTIVITY  \
# Unnamed: 0
# 0            Oceanside, San Diego County        Paddling
# 6                  Piedade Beach, Recife        Swimming
# 8           Cocoa Beach, Brevard  County         Walking
# 10                       Cairns Aquarium  Feeding sharks
# 13                        Off Land's End         Fishing
#
#                               NAME SEX_ AGE            TIME          SPECIES_  \
# Unnamed: 0
# 0                      Julie Wolfe    F  57           18h00       White shark
# 6           Jose Ernesto da Silva     M  18  Late afternoon       Tiger shark
# 8                        Cody High    M  15           17h00    Bull shark, 6'
# 10                            male    M  32         Morning   Grey reef shark
# 13                    Max Berryman    M  21           08h15  Invalid incident
#
#                                       PDF  \
# Unnamed: 0
# 0                    2018.06.25-Wolfe.pdf
# 6                2018.06.03.a-daSilva.pdf
# 8                   2018.05.26.b-High.pdf
# 10          2018.05.24-CairnsAquarium.pdf
# 13              2018.05.13.a-Berryman.pdf
#
#                                                          HREF
# Unnamed: 0
# 0           http://sharkattackfile.net/spreadsheets/pdf_di...
# 6           http://sharkattackfile.net/spreadsheets/pdf_di...
# 8           http://sharkattackfile.net/spreadsheets/pdf_di...
# 10          http://sharkattackfile.net/spreadsheets/pdf_di...
# 13          http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
tiburones_elim.columns
# Out:
# Index(['CASE NUMBER', 'YEAR', 'TYPE', 'COUNTRY', 'AREA', 'LOCATION',
#        'ACTIVITY', 'NAME', 'SEX ', 'AGE', 'TIME', 'SPECIES ', 'PDF', 'HREF'],
#       dtype='object')

# %%
columnas_nuevas = []
for columna in tiburones_elim.columns:
    columnas_nuevas.append(columna.replace(" ", "_"))

# %%
columnas_nuevas2 = [col.replace(" ", "_") for col in tiburones_elim.columns]

# %%
columnas_nuevas[:2]
# Out:
# ['CASE_NUMBER', 'YEAR']

# %%
tiburones_elim.columns = columnas_nuevas
tiburones_elim.head()
# Out:
#              CASE_NUMBER    YEAR        TYPE    COUNTRY        AREA  \
# Unnamed: 0
# 0             2018.06.25  2018.0     Boating        USA  California
# 6           2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8           2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 10            2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 13          2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                                 LOCATION        ACTIVITY  \
# Unnamed: 0
# 0            Oceanside, San Diego County        Paddling
# 6                  Piedade Beach, Recife        Swimming
# 8           Cocoa Beach, Brevard  County         Walking
# 10                       Cairns Aquarium  Feeding sharks
# 13                        Off Land's End         Fishing
#
#                               NAME SEX_ AGE            TIME          SPECIES_  \
# Unnamed: 0
# 0                      Julie Wolfe    F  57           18h00       White shark
# 6           Jose Ernesto da Silva     M  18  Late afternoon       Tiger shark
# 8                        Cody High    M  15           17h00    Bull shark, 6'
# 10                            male    M  32         Morning   Grey reef shark
# 13                    Max Berryman    M  21           08h15  Invalid incident
#
#                                       PDF  \
# Unnamed: 0
# 0                    2018.06.25-Wolfe.pdf
# 6                2018.06.03.a-daSilva.pdf
# 8                   2018.05.26.b-High.pdf
# 10          2018.05.24-CairnsAquarium.pdf
# 13              2018.05.13.a-Berryman.pdf
#
#                                                          HREF
# Unnamed: 0
# 0           http://sharkattackfile.net/spreadsheets/pdf_di...
# 6           http://sharkattackfile.net/spreadsheets/pdf_di...
# 8           http://sharkattackfile.net/spreadsheets/pdf_di...
# 10          http://sharkattackfile.net/spreadsheets/pdf_di...
# 13          http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# ------------------------------------

# %%
ataques.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
ataques.rename(columns = {'Unnamed: 0': 'UNNAMED: 0', 'Case Number': 'CASE NUMBER', 'Year':'YEAR', 'Type': 'TYPE', 'Country': 'COUNTRY', 'Area': 'AREA',
       'Location': 'LOCATION', 'Activity': 'ACTIVITY', 'Name': 'NAME', 'Sex ': 'SEX ', 'Age': 'AGE', 'Time': 'TIME', 'Species ': 'SPECIES ',
       'Investigator or Source' : 'INVESTIGATOR OR SOURCE', 'pdf': 'PDF', 'href formula': 'HREF FORMULA', 'href': 'HREF',
       'Case Number.1': 'CASE NUMBER.1', 'Case Number.2': 'CASE NUMBER.2', 'original order': 'ORIGINAL ORDER', 'Unnamed: 22': 'UNNAMED:22',
       'Unnamed: 23': 'UNNAMED: 23'}, inplace = True)
ataques.head()
# Out:
#    UNNAMED: 0   CASE NUMBER    YEAR        TYPE     COUNTRY             AREA  \
# 0        6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES         St. Anne
# 1        6133  1797.05.28.R  1797.0  Unprovoked         NaN              NaN
# 2        6134    1792.09.12  1792.0    Provoked     ENGLAND              NaN
# 3        6135    1791.00.00  1791.0  Unprovoked   AUSTRALIA  New South Wales
# 4        6136    1788.05.10  1788.0        Boat   AUSTRALIA  New South Wales
#
#               LOCATION                         ACTIVITY  \
# 0                  NaN  a corsair's boat was overturned
# 1                  NaN                Dropped overboard
# 2  On the Thames River                          Fishing
# 3         Port Jackson                              NaN
# 4        Sydney Harbor                          Fishing
#
#                                NAME SEX   ... SPECIES   \
# 0                               NaN    F  ...      NaN
# 1                             child  NaN  ...      NaN
# 2                              male    M  ...      NaN
# 3  female, an Australian aboriginal    F  ...      NaN
# 4                              boat  NaN  ...      NaN
#
#                               INVESTIGATOR OR SOURCE  \
# 0                                 V. C. Harvey-Brain
# 1                             The Observer 5/28/1797
# 2                    The Waterford Herald, 9/15/1792
# 3                 G.P. Whitley;  D. Baldridge, p.162
# 4  G.P. Whitley citing J. Cobley, Sydney Cove, p....
#
#                                PDF  \
# 0      1800.00.00-Corsair-boat.pdf
# 1      1797.05.28.R-Cloverdale.pdf
# 2            1792.09.12-Thames.pdf
# 3  1791.00.00-aboriginal woman.pdf
# 4                1788.05.10-Sydney
#
#                                         HREF FORMULA  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 HREF CASE NUMBER.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    1800.00.00
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  1797.05.28.R
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    1792.09.12
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    1791.00.00
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    1788.05.10
#
#   CASE NUMBER.2 ORIGINAL ORDER UNNAMED:22  UNNAMED: 23
# 0    1800.00.00          171.0        NaN          NaN
# 1  1797.05.28.R          170.0        NaN          NaN
# 2    1792.09.12          169.0        NaN          NaN
# 3    1791.00.00          168.0        NaN          NaN
# 4    1788.05.10          167.0        NaN          NaN
#
# [5 rows x 22 columns]

# %%
ataques_sinespacios = ataques.replace(" ", "_")
ataques_sinespacios.head()
# Out:
#    UNNAMED: 0   CASE NUMBER    YEAR        TYPE     COUNTRY             AREA  \
# 0        6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES         St. Anne
# 1        6133  1797.05.28.R  1797.0  Unprovoked         NaN              NaN
# 2        6134    1792.09.12  1792.0    Provoked     ENGLAND              NaN
# 3        6135    1791.00.00  1791.0  Unprovoked   AUSTRALIA  New South Wales
# 4        6136    1788.05.10  1788.0        Boat   AUSTRALIA  New South Wales
#
#               LOCATION                         ACTIVITY  \
# 0                  NaN  a corsair's boat was overturned
# 1                  NaN                Dropped overboard
# 2  On the Thames River                          Fishing
# 3         Port Jackson                              NaN
# 4        Sydney Harbor                          Fishing
#
#                                NAME SEX   ... SPECIES   \
# 0                               NaN    F  ...      NaN
# 1                             child  NaN  ...      NaN
# 2                              male    M  ...      NaN
# 3  female, an Australian aboriginal    F  ...      NaN
# 4                              boat  NaN  ...      NaN
#
#                               INVESTIGATOR OR SOURCE  \
# 0                                 V. C. Harvey-Brain
# 1                             The Observer 5/28/1797
# 2                    The Waterford Herald, 9/15/1792
# 3                 G.P. Whitley;  D. Baldridge, p.162
# 4  G.P. Whitley citing J. Cobley, Sydney Cove, p....
#
#                                PDF  \
# 0      1800.00.00-Corsair-boat.pdf
# 1      1797.05.28.R-Cloverdale.pdf
# 2            1792.09.12-Thames.pdf
# 3  1791.00.00-aboriginal woman.pdf
# 4                1788.05.10-Sydney
#
#                                         HREF FORMULA  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 HREF CASE NUMBER.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    1800.00.00
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  1797.05.28.R
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    1792.09.12
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    1791.00.00
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    1788.05.10
#
#   CASE NUMBER.2 ORIGINAL ORDER UNNAMED:22  UNNAMED: 23
# 0    1800.00.00          171.0        NaN          NaN
# 1  1797.05.28.R          170.0        NaN          NaN
# 2    1792.09.12          169.0        NaN          NaN
# 3    1791.00.00          168.0        NaN          NaN
# 4    1788.05.10          167.0        NaN          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# -----------------------------------------

# %%
ataques_adicional.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Fatal (Y/N)', 'Injury', 'Date'], dtype='object')

# %%
ataques_adicional.rename(columns = {'Unnamed: 0': 'UNNAMED: 0', 'Case Number':'CASE NUMBER', 'Fatal (Y/N)': 'FATAL (Y/N)', 'Injury': 'INJURY', 'Date': 'DATE'}, inplace = True)
ataques_adicional.head()
# Out:
#    UNNAMED: 0 CASE NUMBER FATAL (Y/N)  \
# 0           0  2018.06.25           N
# 1           1  2018.06.18           N
# 2           2  2018.06.09           N
# 3           3  2018.06.08           N
# 4           4  2018.06.04           N
#
#                                               INJURY         DATE
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 1                         Minor injury to left thigh  18-Jun-2018
# 2       Injury to left lower leg from surfboard skeg  09-Jun-2018
# 3                          Minor injury to lower leg  08-Jun-2018
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT  04-Jun-2018

# %% [markdown]
# ----------------------------------------------------------------
# TODAS LAS TABLAS TIENEN EN COMUN LA COLUMA CASE NUMBER

# %% [markdown]
# 3. En este momento nos habremos dado cuenta que el DataFrame que generamos en el pair programming Pandas IV es similar al DataFrame de los datos historicos. Si recordamos, eliminamos algunas columnas en la sesión III que no eran útiles, pero esas columnas están todavía en el histórico. Si no fuera por eso podríamos unir esos dataframes. Realizad los cambios que creais necesarios para que los dataframes sean iguales y luego juntadlos usando el mejor método.

# %%
#primero un concat de las grandes y depues hacer un merge con la pequeña

# %%
tablas_unidas1 = pd.concat([tiburones_sinespacios, ataques_sinespacios], axis=0, ignore_index = True)
tablas_unidas1.head()
# Out:
#     CASE_NUMBER    YEAR        TYPE    COUNTRY        AREA  \
# 0    2018.06.25  2018.0     Boating        USA  California
# 1  2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 2  2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 3    2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 4  2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                        LOCATION        ACTIVITY                    NAME SEX_  \
# 0   Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 1         Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 2  Cocoa Beach, Brevard  County         Walking               Cody High    M
# 3               Cairns Aquarium  Feeding sharks                    male    M
# 4                Off Land's End         Fishing            Max Berryman    M
#
#   AGE  ... CASE NUMBER SEX  SPECIES  INVESTIGATOR OR SOURCE  HREF FORMULA  \
# 0  57  ...         NaN  NaN      NaN                    NaN           NaN
# 1  18  ...         NaN  NaN      NaN                    NaN           NaN
# 2  15  ...         NaN  NaN      NaN                    NaN           NaN
# 3  32  ...         NaN  NaN      NaN                    NaN           NaN
# 4  21  ...         NaN  NaN      NaN                    NaN           NaN
#
#   CASE NUMBER.1 CASE NUMBER.2 ORIGINAL ORDER UNNAMED:22 UNNAMED: 23
# 0           NaN           NaN            NaN        NaN         NaN
# 1           NaN           NaN            NaN        NaN         NaN
# 2           NaN           NaN            NaN        NaN         NaN
# 3           NaN           NaN            NaN        NaN         NaN
# 4           NaN           NaN            NaN        NaN         NaN
#
# [5 rows x 25 columns]

# %%
tablas_unidas2 = tablas_unidas1.merge(ataques_adicional, on='CASE NUMBER')
tablas_unidas2.head()
# Out:
#     CASE_NUMBER    YEAR        TYPE    COUNTRY        AREA  \
# 0    2018.06.25  2018.0     Boating        USA  California
# 1  2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 2  2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 3    2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 4  2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                        LOCATION        ACTIVITY                    NAME SEX_  \
# 0   Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 1         Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 2  Cocoa Beach, Brevard  County         Walking               Cody High    M
# 3               Cairns Aquarium  Feeding sharks                    male    M
# 4                Off Land's End         Fishing            Max Berryman    M
#
#   AGE  ... HREF FORMULA CASE NUMBER.1 CASE NUMBER.2 ORIGINAL ORDER  \
# 0  57  ...          NaN           NaN           NaN            NaN
# 1  18  ...          NaN           NaN           NaN            NaN
# 2  15  ...          NaN           NaN           NaN            NaN
# 3  32  ...          NaN           NaN           NaN            NaN
# 4  21  ...          NaN           NaN           NaN            NaN
#
#    UNNAMED:22 UNNAMED: 23 UNNAMED: 0_y FATAL (Y/N)  \
# 0         NaN         NaN         5472           N
# 1         NaN         NaN         5472           N
# 2         NaN         NaN         5472           N
# 3         NaN         NaN         5472           N
# 4         NaN         NaN         5472           N
#
#                                               INJURY                  DATE
# 0  Lacerations to leg from hooked shark PROVOKED ...  Reported 06-Sep-1905
# 1  Lacerations to leg from hooked shark PROVOKED ...  Reported 06-Sep-1905
# 2  Lacerations to leg from hooked shark PROVOKED ...  Reported 06-Sep-1905
# 3  Lacerations to leg from hooked shark PROVOKED ...  Reported 06-Sep-1905
# 4  Lacerations to leg from hooked shark PROVOKED ...  Reported 06-Sep-1905
#
# [5 rows x 29 columns]

# %%
tablas_unidas2.columns
# Out:
# Index(['CASE_NUMBER', 'YEAR', 'TYPE', 'COUNTRY', 'AREA', 'LOCATION',
#        'ACTIVITY', 'NAME', 'SEX_', 'AGE', 'TIME', 'SPECIES_', 'PDF', 'HREF',
#        'UNNAMED: 0_x', 'CASE NUMBER', 'SEX ', 'SPECIES ',
#        'INVESTIGATOR OR SOURCE', 'HREF FORMULA', 'CASE NUMBER.1',
#        'CASE NUMBER.2', 'ORIGINAL ORDER', 'UNNAMED:22', 'UNNAMED: 23',
#        'UNNAMED: 0_y', 'FATAL (Y/N)', 'INJURY', 'DATE'],
#       dtype='object')

# %% [markdown]
# 4. Es el momento de unir la información de todos los ataques de tiburón que acabamos de crear con el DataFrame de información adicional. Debatid que método es el más correcto para unir toda esta información y ejecutadlo.
#
# 📌 NOTA Cuando hagáis la unión considerad que la información que más nos interesa es la del DataFrame que creamos en el apartado anterior, lo cual determinará el tipo de unión.

# %% [markdown]
# 5. Guardad el dataframe nuevo en un csv que usaremos mañana en la clase de pair programming

# %%
tablas_unidas2.to_csv("tablas_unidas2.csv", index=False)
