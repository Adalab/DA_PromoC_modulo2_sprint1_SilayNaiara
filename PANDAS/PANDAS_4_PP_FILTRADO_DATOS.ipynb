# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Pair Programming Pandas IV**

# %% [markdown]
# 1. Cargad el csv que guardasteis ayer.

# %%
tiburones_eliminadas = pd.read_csv("tiburones_eliminadas.csv", index_col= 0)
tiburones_eliminadas
# Out:
#       UNNAMED: 0   CASE NUMBER    YEAR          TYPE    COUNTRY  \
# 0              0    2018.06.25  2018.0       Boating        USA
# 1              1    2018.06.18  2018.0    Unprovoked        USA
# 2              2    2018.06.09  2018.0       Invalid        USA
# 3              3    2018.06.08  2018.0    Unprovoked  AUSTRALIA
# 4              4    2018.06.04  2018.0      Provoked     MEXICO
# ...          ...           ...     ...           ...        ...
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    AREA                          LOCATION  \
# 0            California       Oceanside, San Diego County
# 1               Georgia    St. Simon Island, Glynn County
# ...

# %% [markdown]
# Antes de seguir con las preguntas, este DataFrame está terriblemente sucio.
#
# En las próximas sesiones lo iremos limpiando. Para evitar posibles errores con los nulos vamos a eliminar todos los nulos del DataFrame.
#
#
# Para ello vamos a utilizar el método .dropna() de pandas. Tendréis que ejecutar la siguiente línea de código para eliminar los nulos del DataFrame y poder seguir haciendo el resto de los ejercicios.
#
#
# df.dropna(inplace = True)
#
#
# ¿Cuántas filas se han eliminado con esta línea de código?

# %%
sin_nulos = tiburones_eliminadas.dropna()
sin_nulos.head()
# Out:
#     UNNAMED: 0   CASE NUMBER    YEAR        TYPE    COUNTRY        AREA  \
# 0            0    2018.06.25  2018.0     Boating        USA  California
# 6            6  2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8            8  2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 10          10    2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 13          13  2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                         LOCATION        ACTIVITY                    NAME SEX   \
# 0    Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 6          Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 8   Cocoa Beach, Brevard  County         Walking               Cody High    M
# 10               Cairns Aquarium  Feeding sharks                    male    M
# 13                Off Land's End         Fishing            Max Berryman    M
#
# ...

# %% [markdown]
# 2. ¿Cuál es el número de ataques que se han producido en Estados Unidos?

# %%
ataques_usa = sin_nulos[sin_nulos["COUNTRY"].str.contains("USA")]
ataques_usa.head()
# Out:
#     UNNAMED: 0   CASE NUMBER    YEAR        TYPE COUNTRY        AREA  \
# 0            0    2018.06.25  2018.0     Boating     USA  California
# 8            8  2018.05.26.b  2018.0  Unprovoked     USA     Florida
# 35          35    2018.03.31  2018.0  Unprovoked     USA      Hawaii
# 53          53    2017.12.31  2017.0  Unprovoked     USA      Hawaii
# 60          60    2017.11.24  2017.0  Unprovoked     USA  California
#
#                             LOCATION                 ACTIVITY  \
# 0        Oceanside, San Diego County                 Paddling
# 8       Cocoa Beach, Brevard  County                  Walking
# 35                       Kukio Beach  Stand-Up Paddleboarding
# 53              Hultin's Beach, Oahu                  Surfing
# 60  Stillwater Cove, Monterey County             Spearfishing
#
#                 NAME SEX  AGE   TIME            SPECIES   \
# 0        Julie Wolfe    F  57  18h00         White shark
# 8          Cody High    M  15  17h00      Bull shark, 6'
# ...

# %% [markdown]
# 3. ¿Y en España?

# %%
columna_paises = sin_nulos["COUNTRY"].unique()
columna_paises
# Out:
# array(['USA', 'BRAZIL', 'AUSTRALIA', 'ENGLAND', 'COSTA RICA', 'MALDIVES',
#        'SOUTH AFRICA', 'CUBA', 'SPAIN', 'BAHAMAS', 'INDONESIA', 'EGYPT',
#        'NEW ZEALAND', 'FRENCH POLYNESIA', 'NEW CALEDONIA', 'ECUADOR',
#        'THAILAND', 'REUNION', 'MEXICO', 'JAMAICA', 'ITALY',
#        'PAPUA NEW GUINEA', 'RUSSIA', 'SEYCHELLES', 'VIETNAM', 'GUAM',
#        'MOZAMBIQUE', 'SCOTLAND', 'UNITED KINGDOM', 'TAIWAN', 'CROATIA',
#        'FIJI', 'TONGA', 'ST. MAARTIN', 'GRAND CAYMAN', 'VANUATU',
#        'VENEZUELA', 'TURKS & CAICOS', 'OKINAWA', 'MARSHALL ISLANDS',
#        'MAURITIUS', 'HONG KONG', 'JAPAN', 'SOUTH KOREA', 'ISRAEL',
#        'MICRONESIA', 'COLUMBIA', 'NEW BRITAIN', 'PALAU',
#        'SOLOMON ISLANDS', 'FEDERATED STATES OF MICRONESIA', 'GREECE',
#        'BRITISH WEST INDIES', 'NORTH PACIFIC OCEAN', 'BERMUDA',
#        'PHILIPPINES', 'AMERICAN SAMOA', 'PACIFIC OCEAN', 'SENEGAL',
#        'ARGENTINA', 'EL SALVADOR', 'IRAQ', 'PANAMA', 'INDIA'],
#       dtype=object)

# %%
ataques_spain = sin_nulos[sin_nulos["COUNTRY"].str.contains("SPAIN")]
ataques_spain.head()
# Out:
#       UNNAMED: 0   CASE NUMBER    YEAR        TYPE COUNTRY  \
# 98            98  2017.08.26.b  2017.0     Invalid   SPAIN
# 233          234    2016.07.29  2016.0  Unprovoked   SPAIN
# 377          378  2015.08.18.a  2015.0     Invalid   SPAIN
# 1007        1011  2010.07.16.b  2010.0    Provoked   SPAIN
# 2469        2476    1993.09.03  1993.0  Unprovoked   SPAIN
#
#                      AREA                        LOCATION  ACTIVITY  \
# 98              Castellón                 Grao de Moncofa  Swimming
# 233     Alicante Province                Arenales del Sol  Swimming
# 377              Alicante        Poniente Beach, Benidorm  Swimming
# 1007  Grand Canary Island       Sardina del Norte, Gáldar  Swimming
# 2469         Costa Blanca  Playa de las Arenas, Valencia   Swimming
#
#                                      NAME SEX  AGE    TIME  \
# 98                                 female    F  11  Midday
# 233                                  male    M  40   11h30
# ...

# %% [markdown]
# 3.1 ¿En qué regiones se han producido los ataques (columna location) ?

# %%
regiones_españa = sin_nulos[(sin_nulos["COUNTRY"] == "SPAIN") & (sin_nulos["LOCATION"])]
regiones_españa
# Out:
#       UNNAMED: 0   CASE NUMBER    YEAR        TYPE COUNTRY  \
# 98            98  2017.08.26.b  2017.0     Invalid   SPAIN
# 233          234    2016.07.29  2016.0  Unprovoked   SPAIN
# 377          378  2015.08.18.a  2015.0     Invalid   SPAIN
# 1007        1011  2010.07.16.b  2010.0    Provoked   SPAIN
# 2469        2476    1993.09.03  1993.0  Unprovoked   SPAIN
#
#                      AREA                        LOCATION  ACTIVITY  \
# 98              Castellón                 Grao de Moncofa  Swimming
# 233     Alicante Province                Arenales del Sol  Swimming
# 377              Alicante        Poniente Beach, Benidorm  Swimming
# 1007  Grand Canary Island       Sardina del Norte, Gáldar  Swimming
# 2469         Costa Blanca  Playa de las Arenas, Valencia   Swimming
#
#                                      NAME SEX  AGE    TIME  \
# 98                                 female    F  11  Midday
# 233                                  male    M  40   11h30
# ...

# %% [markdown]
# 3.2 ¿Cuántos ataques se han producido en cada área (columna area)?

# %%
#5, por que es el numero de filas que nos ha salido.

# %% [markdown]
# 4. Extraed un DataFrame nuevo con los ataques que se han producido en Australia y Estados Unidos.
#
# 📌 Nota Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método isin(). Hacedlo con ambas herramientas.

# %%
ataques_usa_australia = sin_nulos[sin_nulos["COUNTRY"].isin(["USA", "AUSTRALIA"])]
ataques_usa_australia.head()
# Out:
#     UNNAMED: 0   CASE NUMBER    YEAR        TYPE    COUNTRY  \
# 0            0    2018.06.25  2018.0     Boating        USA
# 8            8  2018.05.26.b  2018.0  Unprovoked        USA
# 10          10    2018.05.24  2018.0    Provoked  AUSTRALIA
# 21          21  2018.04.25.a  2018.0  Unprovoked  AUSTRALIA
# 35          35    2018.03.31  2018.0  Unprovoked        USA
#
#                  AREA                      LOCATION                 ACTIVITY  \
# 0          California   Oceanside, San Diego County                 Paddling
# 8             Florida  Cocoa Beach, Brevard  County                  Walking
# 10         Queensland               Cairns Aquarium           Feeding sharks
# 21  Western Australia       Surfers Point, Prevelly                  Surfing
# 35             Hawaii                   Kukio Beach  Stand-Up Paddleboarding
#
#            NAME SEX  AGE     TIME          SPECIES   \
# 0   Julie Wolfe    F  57    18h00       White shark
# ...

# %% [markdown]
# 4.1 ¿Cuántos ataques se han producido en cada país?

# %%
ataques_usa = sin_nulos[(sin_nulos["COUNTRY"]==("USA"))]
ataques_usa.head()
# Out:
#     UNNAMED: 0   CASE NUMBER    YEAR        TYPE COUNTRY        AREA  \
# 0            0    2018.06.25  2018.0     Boating     USA  California
# 8            8  2018.05.26.b  2018.0  Unprovoked     USA     Florida
# 35          35    2018.03.31  2018.0  Unprovoked     USA      Hawaii
# 53          53    2017.12.31  2017.0  Unprovoked     USA      Hawaii
# 60          60    2017.11.24  2017.0  Unprovoked     USA  California
#
#                             LOCATION                 ACTIVITY  \
# 0        Oceanside, San Diego County                 Paddling
# 8       Cocoa Beach, Brevard  County                  Walking
# 35                       Kukio Beach  Stand-Up Paddleboarding
# 53              Hultin's Beach, Oahu                  Surfing
# 60  Stillwater Cove, Monterey County             Spearfishing
#
#                 NAME SEX  AGE   TIME            SPECIES   \
# 0        Julie Wolfe    F  57  18h00         White shark
# 8          Cody High    M  15  17h00      Bull shark, 6'
# ...

# %%
ataquesusa_index = ataques_usa.index
ataquesusa_index
# Out:
# Int64Index([   0,    8,   35,   53,   60,   74,   75,   79,   87,  100,
#             ...
#             4358, 4387, 4449, 4543, 4558, 4731, 4734, 4862, 5136, 5297],
#            dtype='int64', length=719)

# %%
suma_ataquesusa = len(ataquesusa_index)
suma_ataquesusa
# Out:
# 719

# %%
ataques_australia = sin_nulos[(sin_nulos["COUNTRY"]==("AUSTRALIA"))]
ataques_australia.head()
# Out:
#     UNNAMED: 0   CASE NUMBER    YEAR        TYPE    COUNTRY  \
# 10          10    2018.05.24  2018.0    Provoked  AUSTRALIA
# 21          21  2018.04.25.a  2018.0  Unprovoked  AUSTRALIA
# 36          36    2018.03.14  2018.0  Unprovoked  AUSTRALIA
# 37          37  2018.03.09.b  2018.0  Unprovoked  AUSTRALIA
# 38          38  2018.03.09.a  2018.0  Unprovoked  AUSTRALIA
#
#                  AREA                 LOCATION        ACTIVITY  \
# 10         Queensland          Cairns Aquarium  Feeding sharks
# 21  Western Australia  Surfers Point, Prevelly         Surfing
# 36  Western Australia           Waterman's Bay          Wading
# 37           Victoria                    Lorne        Swimming
# 38           Victoria                 Winkipop         Surfing
#
#                     NAME SEX  AGE     TIME         SPECIES   \
# 10                  male    M  32  Morning  Grey reef shark
# 21             Rob Bruce    M  60    09h30        3 m shark
# ...

# %%
ataquesaustralia_index = ataques_australia.index
ataquesaustralia_index
# Out:
# Int64Index([  10,   21,   36,   37,   38,   40,   42,   63,   66,   71,
#             ...
#             5180, 5203, 5216, 5218, 5259, 5359, 5481, 5631, 5667, 5797],
#            dtype='int64', length=324)

# %%
suma_ataquesaustralia = len(ataquesaustralia_index)
suma_ataquesaustralia
# Out:
# 324

# %% [markdown]
# 4.2 ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el DataFrame en la columna activity)?

# %%
ataques_australia_remando = ataques_australia[ataques_australia["ACTIVITY"]==("Paddling")]
ataques_australia_remando.head()
# Out:
# Empty DataFrame
# Columns: [UNNAMED: 0, CASE NUMBER, YEAR, TYPE, COUNTRY, AREA, LOCATION, ACTIVITY, NAME, SEX , AGE, TIME, SPECIES , PDF, HREF]
# Index: []

# %%
ataques_australia_remando.shape
# Out:
# (0, 15)

# %%
#hay cero ataques remando en australia

# %% [markdown]
# 4.3 ¿Cuántos ataques se han producido en Australia antes del 2000?

# %%
ataques_australia_antes2000 = ataques_australia[(ataques_australia["YEAR"] < (2000))]
ataques_australia_antes2000.head()
# Out:
#       UNNAMED: 0    CASE NUMBER    YEAR        TYPE    COUNTRY  \
# 2116        2123     1999.05.29  1999.0  Unprovoked  AUSTRALIA
# 2129        2136     1999.02.23  1999.0  Unprovoked  AUSTRALIA
# 2174        2181   1998.06.28.a  1998.0  Unprovoked  AUSTRALIA
# 2194        2201  1998.01.28.R   1998.0     Invalid  AUSTRALIA
# 2207        2214     1997.11.09  1997.0  Unprovoked  AUSTRALIA
#
#                    AREA                        LOCATION  \
# 2116    South Australia  Hardwicke Bay, Yorke Peninsula
# 2129    New South Wales                     Scotts Head
# 2174    South Australia            South Neptune Island
# 2194    New South Wales                     Whale Beach
# 2207  Western Australia                          Albany
#
#                                        ACTIVITY           NAME SEX  AGE  \
# 2116                                Windsurfing  Tony Donoghue    M  22
# 2129                                    Surfing           male    M  35
# ...

# %%
ataques_australia_antes2000_index =ataques_australia_antes2000.index
ataques_australia_antes2000_index
# Out:
# Int64Index([2116, 2129, 2174, 2194, 2207, 2252, 2256, 2257, 2304, 2306,
#             ...
#             5180, 5203, 5216, 5218, 5259, 5359, 5481, 5631, 5667, 5797],
#            dtype='int64', length=151)

# %%
suma_ataquesaustralia_antes2000 = len(ataques_australia_antes2000_index)
suma_ataquesaustralia_antes2000
# Out:
# 151

# %% [markdown]
# 4.4 ¿Y después del 2000?

# %%
ataques_australia_despues2000 = ataques_australia[(ataques_australia["YEAR"] > (2000))]
ataques_australia_despues2000.head()
# Out:
#     UNNAMED: 0   CASE NUMBER    YEAR        TYPE    COUNTRY  \
# 10          10    2018.05.24  2018.0    Provoked  AUSTRALIA
# 21          21  2018.04.25.a  2018.0  Unprovoked  AUSTRALIA
# 36          36    2018.03.14  2018.0  Unprovoked  AUSTRALIA
# 37          37  2018.03.09.b  2018.0  Unprovoked  AUSTRALIA
# 38          38  2018.03.09.a  2018.0  Unprovoked  AUSTRALIA
#
#                  AREA                 LOCATION        ACTIVITY  \
# 10         Queensland          Cairns Aquarium  Feeding sharks
# 21  Western Australia  Surfers Point, Prevelly         Surfing
# 36  Western Australia           Waterman's Bay          Wading
# 37           Victoria                    Lorne        Swimming
# 38           Victoria                 Winkipop         Surfing
#
#                     NAME SEX  AGE     TIME         SPECIES   \
# 10                  male    M  32  Morning  Grey reef shark
# 21             Rob Bruce    M  60    09h30        3 m shark
# ...

# %%
ataques_australia_despues2000_index = ataques_australia_despues2000.index
ataques_australia_despues2000_index
# Out:
# Int64Index([  10,   21,   36,   37,   38,   40,   42,   63,   66,   71,
#             ...
#             1790, 1791, 1799, 1858, 1874, 1876, 1877, 1888, 1961, 1969],
#            dtype='int64', length=167)

# %%
suma_ataquesaustralia_despues2000 = len(ataques_australia_despues2000_index)
suma_ataquesaustralia_despues2000
# Out:
# 167

# %% [markdown]
# 5. Extraed unicamente los ataques a mujeres.

# %%
ataques_mujeres = sin_nulos[(sin_nulos["SEX "]==("F"))]
ataques_mujeres.head()
# Out:
#     UNNAMED: 0 CASE NUMBER    YEAR        TYPE    COUNTRY             AREA  \
# 0            0  2018.06.25  2018.0     Boating        USA       California
# 40          40  2018.02.23  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 53          53  2017.12.31  2017.0  Unprovoked        USA           Hawaii
# 71          71  2017.10.22  2017.0  Unprovoked  AUSTRALIA  South Australia
# 75          75  2017.10.05  2017.0  Unprovoked        USA           Hawaii
#
#                               LOCATION            ACTIVITY              NAME  \
# 0          Oceanside, San Diego County            Paddling       Julie Wolfe
# 40  Little Congwong Beach, La Perouse             Swimming    Anna Shurapey
# 53                Hultin's Beach, Oahu             Surfing  Marjorie Mariano
# 71                         Normanville  Kayaking / Fishing    Sarah Williams
# 75          Kamaole Beach Park, Maui           Snorkeling            female
#
# ...

# %% [markdown]
# 6. ¿Cuántas mujeres fueron atacadas en España?

# %%
#no va
ataques_mujeres_españa = sin_nulos[(sin_nulos["SEX "]==("F"))]
ataques_mujeres_españa.head()
# Out:
#     UNNAMED: 0 CASE NUMBER    YEAR        TYPE    COUNTRY             AREA  \
# 0            0  2018.06.25  2018.0     Boating        USA       California
# 40          40  2018.02.23  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 53          53  2017.12.31  2017.0  Unprovoked        USA           Hawaii
# 71          71  2017.10.22  2017.0  Unprovoked  AUSTRALIA  South Australia
# 75          75  2017.10.05  2017.0  Unprovoked        USA           Hawaii
#
#                               LOCATION            ACTIVITY              NAME  \
# 0          Oceanside, San Diego County            Paddling       Julie Wolfe
# 40  Little Congwong Beach, La Perouse             Swimming    Anna Shurapey
# 53                Hultin's Beach, Oahu             Surfing  Marjorie Mariano
# 71                         Normanville  Kayaking / Fishing    Sarah Williams
# 75          Kamaole Beach Park, Maui           Snorkeling            female
#
# ...

# %% [markdown]
# 7. Extraed los ataques que se hayan producido en el año 2000, 1997 y 2006. Utilizad el método isin() para resolver este ejercicio.

# %%
ataques_años = sin_nulos[sin_nulos["YEAR"].isin([1997, 2000, 2006])]
ataques_años.head()
# Out:
#       UNNAMED: 0 CASE NUMBER    YEAR        TYPE       COUNTRY  \
# 1407        1412  2006.12.18  2006.0  Unprovoked     AUSTRALIA
# 1408        1413  2006.12.11  2006.0  Unprovoked   NEW ZEALAND
# 1409        1414  2006.12.10  2006.0  Unprovoked           USA
# 1410        1415  2006.12.06  2006.0    Provoked  SOUTH AFRICA
# 1411        1416  2006.12.02  2006.0  Unprovoked     AUSTRALIA
#
#                    AREA                    LOCATION       ACTIVITY  \
# 1407           Victoria      Winki Pop, Bells Beach        Surfing
# 1408       North Island            Raglan, Manu Bay        Surfing
# 1409         California  Dillon Beach, Marin County        Surfing
# 1410      KwaZulu-Natal                  Cape Vidal        Fishing
# 1411  Western Australia               Wharton Beach  Body boarding
#
#                       NAME SEX  AGE       TIME                   SPECIES   \
# 1407          Peter Galvin    M  25      20h00           2.5 to 3 m shark
# ...

# %% [markdown]
# 8. Si extraemos los valores únicos de la columna species nos podemos dar cuenta que está un poco sucia y extraer informacion útil de la misma se puede convertir en algo difícil. En este ejercicio tendréis que extraer los ataques que han ocurrido por tiburón blanco (lo encontraremos en la columna species como algo que contenga white o White). Usad el método str.contains() para resolver este ejercicio.

# %%
sin_nulos.columns
# Out:
# Index(['UNNAMED: 0', 'CASE NUMBER', 'YEAR', 'TYPE', 'COUNTRY', 'AREA',
#        'LOCATION', 'ACTIVITY', 'NAME', 'SEX ', 'AGE', 'TIME', 'SPECIES ',
#        'PDF', 'HREF'],
#       dtype='object')

# %%
sin_nulos['SPECIES '].unique()
# Out:
# array(['White shark', 'Tiger shark', "Bull shark, 6'", 'Grey reef shark',
#        'Invalid incident', '3 m shark', 'White shark, 2.5 m',
#        "Tiger shark, 12'", 'Wobbegong shark', '3.5 m shark',
#        '1.8 m shark', 'Juvenile white shark,  2.7 to 3.2 m',
#        'Bull shark, 2 m', 'small shark', 'White shark, 4.6 m',
#        '2 m shark', 'Wobbegong shark, 1 m', 'White shark, 4.5 m',
#        'Tiger shark, 8 to 10 feet', "8' shark", 'Questionable',
#        "5' to 6' shark", 'White shark, 3 to 3.5m ', 'White shark, 3 m',
#        'Shark involvement questionable', "White shark, 5' to 7'",
#        'Possibly a juvenile blacktip shark', "4' shark", 'A small shark',
#        "White shark, 11' to 13'", "White shark, 8' to 10'",
#        "Bull shark, 4' to 5'", 'White shark, 4 m',
#        'Shark involvement highly doubtful', "Bull shark, 5' to 7'",
#        'Bull shark, 4 m', 'Bull shark, 1 m',
#        'Shark involvement not confirmed', 'Wobbegong shark, 2m',
# ...

# %%
patron = "^white|White\s\w+"

# %%
tiburon_blanco = sin_nulos[sin_nulos["SPECIES "].str.contains(patron, regex=True)]
tiburon_blanco.head()
# Out:
#     UNNAMED: 0 CASE NUMBER    YEAR        TYPE       COUNTRY  \
# 0            0  2018.06.25  2018.0     Boating           USA
# 24          24  2018.04.22  2018.0  Unprovoked  SOUTH AFRICA
# 34          34  2018.04.03  2018.0  Unprovoked  SOUTH AFRICA
# 60          60  2017.11.24  2017.0  Unprovoked           USA
# 71          71  2017.10.22  2017.0  Unprovoked     AUSTRALIA
#
#                      AREA                          LOCATION  \
# 0              California       Oceanside, San Diego County
# 24  Western Cape Province    Robberg Beach, Plettenberg Bay
# 34  Eastern Cape Province                   St. Francis Bay
# 60             California  Stillwater Cove, Monterey County
# 71        South Australia                       Normanville
#
#               ACTIVITY            NAME SEX  AGE       TIME  \
# 0             Paddling     Julie Wolfe    F  57      18h00
# 24       Paddle-skiing            male    M  33      09h40
# ...

# %% [markdown]
# 9. Extraed ahora los ataques por tiburón blanco o tigre. Utilizad el método str.contains() para resolver este ejercicio.

# %%
#tenemos que hacer un patron comun por que no nos deja usar dos patrones.
patron2 = "^white|White|Tiger|tiger\s\w+"

# %%
tiburon_blancoytigre = sin_nulos[sin_nulos["SPECIES "].str.contains(patron2, regex=True)]
tiburon_blancoytigre.head()
# Out:
#     UNNAMED: 0   CASE NUMBER    YEAR        TYPE       COUNTRY  \
# 0            0    2018.06.25  2018.0     Boating           USA
# 6            6  2018.06.03.a  2018.0  Unprovoked        BRAZIL
# 18          18  2018.04.28.b  2018.0  Unprovoked    COSTA RICA
# 23          23    2018.04.23  2018.0  Unprovoked      MALDIVES
# 24          24    2018.04.22  2018.0  Unprovoked  SOUTH AFRICA
#
#                      AREA                        LOCATION       ACTIVITY  \
# 0              California     Oceanside, San Diego County       Paddling
# 6              Pernambuco           Piedade Beach, Recife       Swimming
# 18           Cocos Island                       Manuelita   Scuba diving
# 23      Alifu Alifu Atoll                       Madoogali        Fishing
# 24  Western Cape Province  Robberg Beach, Plettenberg Bay  Paddle-skiing
#
#                       NAME SEX  AGE            TIME            SPECIES   \
# ...

# %%
tiburon_blanco.shape
# Out:
# (241, 15)

# %%
tiburon_blancoytigre.shape
# Out:
# (395, 15)

# %% [markdown]
# 10. Utilizando la columna de year cread una nueva columna llamada siglo que tiene siglo-XX o siglo-XXI. Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.

# %%
sin_nulos["SIGLO"] = np.where(sin_nulos["YEAR"] <= 2000, "SIGLO-XX", "SIGLO-XXI")
sin_nulos
# Out:
# /var/folders/qq/jtqr5_ts3_5frnqgj2ky0sjr0000gn/T/ipykernel_55667/875154222.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sin_nulos["SIGLO"] = np.where(sin_nulos["YEAR"] <= 2000, "SIGLO-XX", "SIGLO-XXI")
#       UNNAMED: 0   CASE NUMBER    YEAR        TYPE       COUNTRY  \
# 0              0    2018.06.25  2018.0     Boating           USA
# 6              6  2018.06.03.a  2018.0  Unprovoked        BRAZIL
# 8              8  2018.05.26.b  2018.0  Unprovoked           USA
# 10            10    2018.05.24  2018.0    Provoked     AUSTRALIA
# 13            13  2018.05.13.a  2018.0     Invalid       ENGLAND
# ...          ...           ...     ...         ...           ...
# ...

# %% [markdown]
# 11. Guardad como un archivo csv nuevo. Lo usaremos en el pair programming de mañana.

# %%
sin_nulos.to_csv("tiburones_menos10.csv", index=False)
